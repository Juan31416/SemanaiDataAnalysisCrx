# %%
import pandas as pd
import pyfpgrowth
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import mlxtend as ml

# %%
df = pd.read_csv('sample_semanai.csv')

# %%
df = df.drop(columns = ['key'])

# %%
gByOrder = df.groupby(["orden", "subGroup"]).size().reset_index(name='count')
basket = (gByOrder.groupby(["orden", "subGroup"])['count']
          .sum().unstack().reset_index().fillna(0)
          .set_index('orden'))

# %%
#The encoding function
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
basket_sets = basket.applymap(encode_units)

# %%
basket_sets
# Out:
# subGroup  BEBIDAS  BEBIDAS CON ALCOHOL  BEBIDAS SIN ALCOHOL  BEBIDAS SÚPER  \
# orden
# 1               0                    1                    1              0
# 2               0                    1                    1              1
# 3               0                    1                    1              0
# 4               1                    1                    1              0
# 5               0                    1                    1              1
# ...           ...                  ...                  ...            ...
# 277             0                    0                    0              0
# 278             0                    1                    1              0
# 282             0                    0                    0              0
# 284             0                    0                    0              0
# 286             0                    0                    1              0
#
# subGroup  BÁSICOS  CLÁSICOS  DESTILADOS  ENSALADAS  ENTRADAS  EXTRAS BARRA  \
# orden
# 1               1         1           1          1         1             0
# 2               1         1           0          1         1             0
# 3               1         1           0          1         1             0
# 4               1         1           1          1         1             0
# 5               1         1           0          1         1             0
# ...           ...       ...         ...        ...       ...           ...
# 277             0         0           0          0         0             0
# 278             0         1           0          0         0             0
# 282             0         1           0          0         0             0
# 284             0         1           0          0         0             0
# 286             0         1           0          0         0             0
#
# subGroup  EXTRAS COCINA  HAMBURGUESAS  PAPAS, PAPAS Y MÁS PAPAS  PASTAS  \
# orden
# 1                     1             1                         1       1
# 2                     1             1                         1       1
# 3                     1             1                         1       1
# 4                     1             1                         1       1
# 5                     1             1                         1       1
# ...                 ...           ...                       ...     ...
# 277                   0             1                         0       0
# 278                   0             1                         1       0
# 282                   0             0                         0       0
# 284                   0             0                         0       0
# 286                   0             1                         0       0
#
# subGroup  POSTRES  SANDWICHES
# orden
# 1               1           1
# 2               1           1
# 3               1           1
# 4               1           1
# 5               1           1
# ...           ...         ...
# 277             0           0
# 278             0           0
# 282             0           0
# 284             0           0
# 286             0           0
#
# [278 rows x 16 columns]

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift")
rules.sort_values('confidence', ascending = False, inplace = True)
rules.head(10)
